# %%
import os
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
# ----> 3 os.__version
#
# AttributeError: module 'os' has no attribute '__version'

# %%
# Cell 1: Imports
from pytube import YouTube
from moviepy.audio.io.AudioFileClip import AudioFileClip
import os
from pathlib import Path

# %%
import os
from yt_dlp import YoutubeDL

def get_video_path(input_path, output_dir="downloads", filename="downloaded_video.mp4"):
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, filename)

    # Use yt_dlp to download video
    ydl_opts = {
        'format': 'mp4',
        'outtmpl': output_path,
        'quiet': False,
    }

    with YoutubeDL(ydl_opts) as ydl:
        ydl.download([input_path])

    return output_path

# %%
# Cell 3: Extract audio from video
def extract_audio(video_path: str, audio_path: str = "audio.wav") -> str:
    clip = AudioFileClip(video_path)
    clip.write_audiofile(audio_path, codec='pcm_s16le')  # WAV format
    clip.close()
    print(f"✅ Audio extracted to: {audio_path}")
    return audio_path

# %%
video = get_video_path("https://youtube.com/shorts/XcS7ih3bZzo?si=r8jogBC1lu1pqL2S")
audio = extract_audio(video)
# Out:
# [youtube] Extracting URL: https://youtube.com/shorts/XcS7ih3bZzo?si=r8jogBC1lu1pqL2S
# [youtube] XcS7ih3bZzo: Downloading webpage
# [youtube] XcS7ih3bZzo: Downloading tv client config
# [youtube] XcS7ih3bZzo: Downloading player f203bbc8-main
# [youtube] XcS7ih3bZzo: Downloading tv player API JSON
# [youtube] XcS7ih3bZzo: Downloading ios player API JSON
# [youtube] XcS7ih3bZzo: Downloading m3u8 information
# [info] XcS7ih3bZzo: Downloading 1 format(s): 18
# [download] Destination: downloads\downloaded_video.mp4
# [download] 100% of    1.69MiB in 00:00:02 at 630.62KiB/s
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.
# ✅ Audio extracted to: audio.wav

# %%
import sys
print("🐍 Python version in container:", sys.version)
# Out:
# 🐍 Python version in container: 3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]
